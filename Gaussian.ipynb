# %% [markdown]
# # Import thư viện

# %%
# Thư viện cơ bản
import numpy as np
import pandas as pd

# Bỏ qua các cảnh báo
import warnings
warnings.filterwarnings('ignore')

from collections import Counter

# Thư viện vẽ biểu đồ
import matplotlib.pyplot as plt
import seaborn as sns   

# Thư viện tiền xử lý dữ liệu, tối ưu hóa mô hình
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.impute import KNNImputer

# Thư viện xây dựng mô hình
from sklearn.naive_bayes import GaussianNB

# Thư viện đánh giá mô hình
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_curve, roc_curve, auc, make_scorer, recall_score, ConfusionMatrixDisplay, precision_score

df = pd.read_csv('water_potability.csv')
df.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
df['Potability'].value_counts()
# 0 - Không uống được
# 1 - Uống được
# Out:
# Potability
# 0    1998
# 1    1278
# Name: count, dtype: int64

# %% [markdown]
# # Tiền xử lý dữ liệu

# %%
df.isnull().sum()[df.isnull().sum() > 0] / len(df) * 100
# Out:
# ph                 14.987790
# Sulfate            23.840049
# Trihalomethanes     4.945055
# dtype: float64

# %%
df[df['Potability'] == 0].describe().T
# Out:
#                   count          mean          std         min           25%  \
# ph               1684.0      7.085378     1.683499    0.000000      6.037723
# Hardness         1998.0    196.733292    31.057540   98.452931    177.823265
# Solids           1998.0  21777.490788  8543.068788  320.942611  15663.057382
# Chloramines      1998.0      7.092175     1.501045    1.683993      6.155640
# Sulfate          1510.0    334.564290    36.745549  203.444521    311.264006
# Conductivity     1998.0    426.730454    80.047317  181.483754    368.498530
# Organic_carbon   1998.0     14.364335     3.334554    4.371899     12.101057
# Trihalomethanes  1891.0     66.303555    16.079320    0.738000     55.706530
# Turbidity        1998.0      3.965800     0.780282    1.450000      3.444062
# Potability       1998.0      0.000000     0.000000    0.000000      0.000000
#
#                           50%           75%           max
# ph                   7.035456      8.155510     14.000000
# Hardness           197.123423    216.120687    304.235912
# Solids           20809.618280  27006.249009  61227.196008
# Chloramines          7.090334      8.066462     12.653362
# Sulfate            333.389426    356.853897    460.107069
# Conductivity       422.229331    480.677198    753.342620
# Organic_carbon      14.293508     16.649485     28.300000
# Trihalomethanes     66.542198     77.277704    120.030077
# Turbidity            3.948076      4.496106      6.739000
# Potability           0.000000      0.000000      0.000000

# %%
df[df['Potability'] == 1].describe().T
# Out:
#                   count          mean          std         min           25%  \
# ph               1101.0      7.073783     1.448048    0.227499      6.179312
# Hardness         1278.0    195.800744    35.547041   47.432000    174.330531
# Solids           1278.0  22383.991018  9101.010208  728.750830  15668.985035
# Chloramines      1278.0      7.169338     1.702988    0.352000      6.094134
# Sulfate           985.0    332.566990    47.692818  129.000000    300.763772
# Conductivity     1278.0    425.383800    82.048446  201.619737    360.939023
# Organic_carbon   1278.0     14.160893     3.263907    2.200000     12.033897
# Trihalomethanes  1223.0     66.539684    16.327419    8.175876     56.014249
# Turbidity        1278.0      3.968328     0.780842    1.492207      3.430909
# Potability       1278.0      1.000000     0.000000    1.000000      1.000000
#
#                           50%           75%           max
# ph                   7.036752      7.933068     13.175402
# Hardness           196.632907    218.003420    323.124000
# Solids           21199.386614  27973.236446  56488.672413
# Chloramines          7.215163      8.199261     13.127000
# Sulfate            331.838167    365.941346    481.030642
# Conductivity       420.712729    484.155911    695.369528
# Organic_carbon      14.162809     16.356245     23.604298
# Trihalomethanes     66.678214     77.380975    124.000000
# Turbidity            3.958576      4.509569      6.494249
# Potability           1.000000      1.000000      1.000000

# %%
# Xem trung bình, trung vị của 3 cột có giá trị null
print(df[df['Potability']==0][['ph','Sulfate','Trihalomethanes']].mean()) 
print('\n')
print(df[df['Potability']==0][['ph','Sulfate','Trihalomethanes']].median())
# Out:
# ph                   7.085378
# Sulfate            334.564290
# Trihalomethanes     66.303555
# dtype: float64
#
#
# ph                   7.035456
# Sulfate            333.389426
# Trihalomethanes     66.542198
# dtype: float64

# %%
df[df['Potability']==1][['ph','Sulfate','Trihalomethanes']].mean()
print('\n')
df[df['Potability']==1][['ph','Sulfate','Trihalomethanes']].median()
# Out:
# ph                   7.036752
# Sulfate            331.838167
# Trihalomethanes     66.678214
# dtype: float64

# %%
for cols in df.columns:
    iqr = df[cols].quantile(0.75) - df[cols].quantile(0.25)
    lower_bound = df[cols].quantile(0.25) - (1.5 * iqr)
    upper_bound = df[cols].quantile(0.75) + (1.5 * iqr)
    df[cols] = np.where(df[cols] > upper_bound, upper_bound, df[cols])
    df[cols] = np.where(df[cols] < lower_bound, lower_bound, df[cols])

# %% [markdown]
# # Chia train test

# %%
X = df.drop('Potability',axis=1)
y = df['Potability']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %% [markdown]
# ## Điền null

# %%
X_train_filled = X_train.copy()
X_test_filled = X_test.copy()

# Tạo dict lưu các imputer đã fit theo nhãn
imputers = {}

# Train
for label_value in [0, 1]:
    group_train_idx = y_train[y_train == label_value].index
    group_train = X_train.loc[group_train_idx]

    imputer = KNNImputer(n_neighbors=5)
    imputed = imputer.fit_transform(group_train)
    imputers[label_value] = imputer

    X_train_filled.loc[group_train_idx] = pd.DataFrame(
        imputed, columns=X_train.columns, index=group_train_idx
    )

# Test
for label_value in [0, 1]:
    group_test_idx = y_test[y_test == label_value].index
    group_test = X_test.loc[group_test_idx]

    imputer = imputers[label_value]
    imputed = imputer.transform(group_test)

    X_test_filled.loc[group_test_idx] = pd.DataFrame(
        imputed, columns=X_test.columns, index=group_test_idx
    )

# %%
print(X_train_filled.isnull().sum()[X_train_filled.isnull().sum() > 0])
print(X_test_filled.isnull().sum()[X_test_filled.isnull().sum() > 0])
# Out:
# Series([], dtype: int64)
# Series([], dtype: int64)

# %%
X_train_filled.shape, X_test_filled.shape
# Out:
# ((2293, 9), (983, 9))

# %%
# Biến đầu vào
X_train_filled.columns
# Out:
# Index(['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
#        'Organic_carbon', 'Trihalomethanes', 'Turbidity'],
#       dtype='object')

# %% [markdown]
# ## Chuẩn hóa

# %%
scaler = StandardScaler()
X_train_filled = scaler.fit_transform(X_train_filled)
X_test_filled = scaler.transform(X_test_filled)

# %% [markdown]
# # Chạy mô hình

# %%
gauss = GaussianNB()
gauss.fit(X_train_filled, y_train)
# Out:
# GaussianNB()

# %%
y_pred = gauss.predict(X_test_filled)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.64      0.91      0.75       600
#          1.0       0.56      0.19      0.28       383
#
#     accuracy                           0.63       983
#    macro avg       0.60      0.55      0.51       983
# weighted avg       0.61      0.63      0.57       983

# %%
cm = confusion_matrix(y_test, y_pred)
display_cm = ConfusionMatrixDisplay(confusion_matrix=cm)
display_cm.plot(cmap='Blues')

# %% [markdown]
# # Tối ưu mô hình

# %%
param = {
    'var_smoothing': np.logspace(0, -9, num=100)
}

scoring=make_scorer(precision_score, pos_label=1)

# %%
grid = GridSearchCV(
    estimator=GaussianNB(),
    param_grid=param,
    scoring=scoring,
    cv=5,                                                 
    n_jobs=-1,
    verbose=1
)

grid.fit(X_train_filled, y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# GridSearchCV(cv=5, estimator=GaussianNB(), n_jobs=-1,
#              param_grid={'var_smoothing': array([1.00000000e+00, 8.11130831e-01, 6.57933225e-01, 5.33669923e-01,
#        4.32876128e-01, 3.51119173e-01, 2.84803587e-01, 2.31012970e-01,
#        1.87381742e-01, 1.51991108e-01, 1.23284674e-01, 1.00000000e-01,
#        8.11130831e-02, 6.57933225e-02, 5.33669923e-02, 4.32876128e-02,
#        3.51119173e-02, 2.8480358...
#        5.33669923e-08, 4.32876128e-08, 3.51119173e-08, 2.84803587e-08,
#        2.31012970e-08, 1.87381742e-08, 1.51991108e-08, 1.23284674e-08,
#        1.00000000e-08, 8.11130831e-09, 6.57933225e-09, 5.33669923e-09,
#        4.32876128e-09, 3.51119173e-09, 2.84803587e-09, 2.31012970e-09,
#        1.87381742e-09, 1.51991108e-09, 1.23284674e-09, 1.00000000e-09])},
#              scoring=make_scorer(precision_score, response_method='predict', pos_label=1),
#              verbose=1)

# %%
grid.best_params_
# Out:
# {'var_smoothing': np.float64(1.0)}

# %%
y_proba = grid.predict_proba(X_test_filled)[:, 1]

# %%
# Tạo 1 chuỗi threshold (ngưỡng) từ 0.0 đến 1.0, bước nhảy 0.01
threshold = np.arange(0.0, 1.01, 0.01)

# 1 mảng lưu kết quả từ confusion matrix (ma trận nhầm lẫn)
res = []

for t in threshold:
    y_pred = (y_proba >= t).astype(int)
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    res.append((t, fp, fn, tp, tn))

# %%
df_thresh = pd.DataFrame(res, columns=['Threshold', 'FP', 'FN', 'TP', 'TN'])
df_thresh['Precision'] = df_thresh['TP'] / (df_thresh['TP'] + df_thresh['FP'])
df_thresh['Recall'] = df_thresh['TP'] / (df_thresh['TP'] + df_thresh['FN'])

# %%
plt.figure(figsize=(10,6))
plt.plot(df_thresh["Threshold"], df_thresh["FP"], label="False Positives", color="red")
plt.plot(df_thresh["Threshold"], df_thresh["FN"], label="False Negatives", color="blue")
plt.xlabel("Threshold")
plt.ylabel("Count")
plt.title("FP & FN vs Threshold")
plt.legend()
plt.grid()
plt.show()

# %%
# In ra confusion matrix & classification report theo nhiều threshold khác nhau
for t in threshold:
    print(f"Threshold: {t:.2f}")
    y_pred = (y_proba >= t).astype(int)
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
# Out:
# Threshold: 0.00
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       600
#          1.0       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.01
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       600
#          1.0       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.02
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       600
#          1.0       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.03
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       600
#          1.0       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.04
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       600
#          1.0       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.05
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       600
#          1.0       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.06
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       600
#          1.0       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.07
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       600
#          1.0       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.08
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       600
#          1.0       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.09
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       600
#          1.0       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.10
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       600
#          1.0       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.11
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       600
#          1.0       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.12
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       600
#          1.0       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.13
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       600
#          1.0       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.14
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       600
#          1.0       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.15
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       600
#          1.0       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.16
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       600
#          1.0       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.17
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       600
#          1.0       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.18
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       600
#          1.0       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.19
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       600
#          1.0       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.20
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       600
#          1.0       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.21
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       600
#          1.0       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.22
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       600
#          1.0       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.23
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       600
#          1.0       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.24
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       600
#          1.0       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.25
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       600
#          1.0       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.26
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       600
#          1.0       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.27
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       600
#          1.0       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.28
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       600
#          1.0       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.29
# [[  2 598]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.00      0.01       600
#          1.0       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.70      0.50      0.28       983
# weighted avg       0.76      0.39      0.22       983
#
# Threshold: 0.30
# [[  5 595]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.01      0.02       600
#          1.0       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.70      0.50      0.29       983
# weighted avg       0.76      0.39      0.23       983
#
# Threshold: 0.31
# [[ 14 586]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.02      0.05       600
#          1.0       0.40      1.00      0.57       383
#
#     accuracy                           0.40       983
#    macro avg       0.70      0.51      0.31       983
# weighted avg       0.76      0.40      0.25       983
#
# Threshold: 0.32
# [[ 31 569]
#  [  2 381]]
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.05      0.10       600
#          1.0       0.40      0.99      0.57       383
#
#     accuracy                           0.42       983
#    macro avg       0.67      0.52      0.33       983
# weighted avg       0.73      0.42      0.28       983
#
# Threshold: 0.33
# [[ 72 528]
#  [ 19 364]]
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.12      0.21       600
#          1.0       0.41      0.95      0.57       383
#
#     accuracy                           0.44       983
#    macro avg       0.60      0.54      0.39       983
# weighted avg       0.64      0.44      0.35       983
#
# Threshold: 0.34
# [[181 419]
#  [ 67 316]]
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.30      0.43       600
#          1.0       0.43      0.83      0.57       383
#
#     accuracy                           0.51       983
#    macro avg       0.58      0.56      0.50       983
# weighted avg       0.61      0.51      0.48       983
#
# Threshold: 0.35
# [[306 294]
#  [143 240]]
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.51      0.58       600
#          1.0       0.45      0.63      0.52       383
#
#     accuracy                           0.56       983
#    macro avg       0.57      0.57      0.55       983
# weighted avg       0.59      0.56      0.56       983
#
# Threshold: 0.36
# [[405 195]
#  [197 186]]
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.68      0.67       600
#          1.0       0.49      0.49      0.49       383
#
#     accuracy                           0.60       983
#    macro avg       0.58      0.58      0.58       983
# weighted avg       0.60      0.60      0.60       983
#
# Threshold: 0.37
# [[464 136]
#  [247 136]]
#               precision    recall  f1-score   support
#
#          0.0       0.65      0.77      0.71       600
#          1.0       0.50      0.36      0.42       383
#
#     accuracy                           0.61       983
#    macro avg       0.58      0.56      0.56       983
# weighted avg       0.59      0.61      0.59       983
#
# Threshold: 0.38
# [[516  84]
#  [285  98]]
#               precision    recall  f1-score   support
#
#          0.0       0.64      0.86      0.74       600
#          1.0       0.54      0.26      0.35       383
#
#     accuracy                           0.62       983
#    macro avg       0.59      0.56      0.54       983
# weighted avg       0.60      0.62      0.58       983
#
# Threshold: 0.39
# [[544  56]
#  [315  68]]
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.91      0.75       600
#          1.0       0.55      0.18      0.27       383
#
#     accuracy                           0.62       983
#    macro avg       0.59      0.54      0.51       983
# weighted avg       0.60      0.62      0.56       983
#
# Threshold: 0.40
# [[552  48]
#  [332  51]]
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.92      0.74       600
#          1.0       0.52      0.13      0.21       383
#
#     accuracy                           0.61       983
#    macro avg       0.57      0.53      0.48       983
# weighted avg       0.58      0.61      0.54       983
#
# Threshold: 0.41
# [[563  37]
#  [338  45]]
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.94      0.75       600
#          1.0       0.55      0.12      0.19       383
#
#     accuracy                           0.62       983
#    macro avg       0.59      0.53      0.47       983
# weighted avg       0.60      0.62      0.53       983
#
# Threshold: 0.42
# [[574  26]
#  [346  37]]
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.96      0.76       600
#          1.0       0.59      0.10      0.17       383
#
#     accuracy                           0.62       983
#    macro avg       0.61      0.53      0.46       983
# weighted avg       0.61      0.62      0.53       983
#
# Threshold: 0.43
# [[581  19]
#  [352  31]]
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.97      0.76       600
#          1.0       0.62      0.08      0.14       383
#
#     accuracy                           0.62       983
#    macro avg       0.62      0.52      0.45       983
# weighted avg       0.62      0.62      0.52       983
#
# Threshold: 0.44
# [[586  14]
#  [358  25]]
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.98      0.76       600
#          1.0       0.64      0.07      0.12       383
#
#     accuracy                           0.62       983
#    macro avg       0.63      0.52      0.44       983
# weighted avg       0.63      0.62      0.51       983
#
# Threshold: 0.45
# [[587  13]
#  [363  20]]
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.98      0.76       600
#          1.0       0.61      0.05      0.10       383
#
#     accuracy                           0.62       983
#    macro avg       0.61      0.52      0.43       983
# weighted avg       0.61      0.62      0.50       983
#
# Threshold: 0.46
# [[588  12]
#  [365  18]]
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.98      0.76       600
#          1.0       0.60      0.05      0.09       383
#
#     accuracy                           0.62       983
#    macro avg       0.61      0.51      0.42       983
# weighted avg       0.61      0.62      0.50       983
#
# Threshold: 0.47
# [[591   9]
#  [370  13]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.98      0.76       600
#          1.0       0.59      0.03      0.06       383
#
#     accuracy                           0.61       983
#    macro avg       0.60      0.51      0.41       983
# weighted avg       0.61      0.61      0.49       983
#
# Threshold: 0.48
# [[593   7]
#  [373  10]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.99      0.76       600
#          1.0       0.59      0.03      0.05       383
#
#     accuracy                           0.61       983
#    macro avg       0.60      0.51      0.40       983
# weighted avg       0.60      0.61      0.48       983
#
# Threshold: 0.49
# [[594   6]
#  [377   6]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.99      0.76       600
#          1.0       0.50      0.02      0.03       383
#
#     accuracy                           0.61       983
#    macro avg       0.56      0.50      0.39       983
# weighted avg       0.57      0.61      0.47       983
#
# Threshold: 0.50
# [[596   4]
#  [377   6]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.99      0.76       600
#          1.0       0.60      0.02      0.03       383
#
#     accuracy                           0.61       983
#    macro avg       0.61      0.50      0.39       983
# weighted avg       0.61      0.61      0.47       983
#
# Threshold: 0.51
# [[598   2]
#  [378   5]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.71      0.01      0.03       383
#
#     accuracy                           0.61       983
#    macro avg       0.66      0.50      0.39       983
# weighted avg       0.65      0.61      0.47       983
#
# Threshold: 0.52
# [[598   2]
#  [381   2]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.50      0.01      0.01       383
#
#     accuracy                           0.61       983
#    macro avg       0.56      0.50      0.38       983
# weighted avg       0.57      0.61      0.47       983
#
# Threshold: 0.53
# [[598   2]
#  [382   1]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.33      0.00      0.01       383
#
#     accuracy                           0.61       983
#    macro avg       0.47      0.50      0.38       983
# weighted avg       0.50      0.61      0.46       983
#
# Threshold: 0.54
# [[599   1]
#  [382   1]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.50      0.00      0.01       383
#
#     accuracy                           0.61       983
#    macro avg       0.56      0.50      0.38       983
# weighted avg       0.57      0.61      0.46       983
#
# Threshold: 0.55
# [[599   1]
#  [382   1]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.50      0.00      0.01       383
#
#     accuracy                           0.61       983
#    macro avg       0.56      0.50      0.38       983
# weighted avg       0.57      0.61      0.46       983
#
# Threshold: 0.56
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.57
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.58
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.59
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.60
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.61
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.62
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.63
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.64
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.65
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.66
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.67
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.68
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.69
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.70
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.71
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.72
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.73
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.74
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.75
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.76
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.77
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.78
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.79
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.80
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.81
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.82
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.83
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.84
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.85
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.86
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.87
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.88
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.89
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.90
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.91
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.92
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.93
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.94
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.95
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.96
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.97
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.98
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.99
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 1.00
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.61      1.00      0.76       600
#          1.0       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983

# %%
y_pred_best = (y_proba >= 0.44).astype(int)

# %%
print(classification_report(y_test, y_pred_best))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.98      0.76       600
#          1.0       0.64      0.07      0.12       383
#
#     accuracy                           0.62       983
#    macro avg       0.63      0.52      0.44       983
# weighted avg       0.63      0.62      0.51       983

# %%
cm_best = confusion_matrix(y_test, y_pred_best)
display_cm_best = ConfusionMatrixDisplay(confusion_matrix=cm_best)
display_cm_best.plot(cmap='Blues')

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_proba)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label='AUC = %0.2f' % roc_auc)
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')  # đường random guess
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()
