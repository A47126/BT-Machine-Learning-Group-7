# %% [markdown]
# # Import thư viện

# %%
# Thư viện cơ bản
import numpy as np
import pandas as pd

# Bỏ qua các cảnh báo
import warnings
warnings.filterwarnings('ignore')

from collections import Counter

# Thư viện vẽ biểu đồ
import matplotlib.pyplot as plt
import seaborn as sns   

# Thư viện tiền xử lý dữ liệu, tối ưu hóa mô hình
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.impute import KNNImputer

# Thư viện xây dựng mô hình
from sklearn.tree import DecisionTreeClassifier, plot_tree

# Thư viện đánh giá mô hình
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_curve, roc_curve, auc, ConfusionMatrixDisplay, make_scorer, recall_score, precision_score

df = pd.read_csv('water_potability.csv')
df.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
df['Potability'].value_counts()
# 0 - Không uống được
# 1 - Uống được
# Out:
# Potability
# 0    1998
# 1    1278
# Name: count, dtype: int64

# %% [markdown]
# # Tiền xử lý dữ liệu

# %%
df.isnull().sum()[df.isnull().sum() > 0] / len(df) * 100
# Out:
# ph                 14.987790
# Sulfate            23.840049
# Trihalomethanes     4.945055
# dtype: float64

# %%
df[df['Potability'] == 0].describe().T
# Out:
#                   count          mean          std         min           25%  \
# ph               1684.0      7.085378     1.683499    0.000000      6.037723
# Hardness         1998.0    196.733292    31.057540   98.452931    177.823265
# Solids           1998.0  21777.490788  8543.068788  320.942611  15663.057382
# Chloramines      1998.0      7.092175     1.501045    1.683993      6.155640
# Sulfate          1510.0    334.564290    36.745549  203.444521    311.264006
# Conductivity     1998.0    426.730454    80.047317  181.483754    368.498530
# Organic_carbon   1998.0     14.364335     3.334554    4.371899     12.101057
# Trihalomethanes  1891.0     66.303555    16.079320    0.738000     55.706530
# Turbidity        1998.0      3.965800     0.780282    1.450000      3.444062
# Potability       1998.0      0.000000     0.000000    0.000000      0.000000
#
#                           50%           75%           max
# ph                   7.035456      8.155510     14.000000
# Hardness           197.123423    216.120687    304.235912
# Solids           20809.618280  27006.249009  61227.196008
# Chloramines          7.090334      8.066462     12.653362
# Sulfate            333.389426    356.853897    460.107069
# Conductivity       422.229331    480.677198    753.342620
# Organic_carbon      14.293508     16.649485     28.300000
# Trihalomethanes     66.542198     77.277704    120.030077
# Turbidity            3.948076      4.496106      6.739000
# Potability           0.000000      0.000000      0.000000

# %%
df[df['Potability'] == 1].describe().T
# Out:
#                   count          mean          std         min           25%  \
# ph               1101.0      7.073783     1.448048    0.227499      6.179312
# Hardness         1278.0    195.800744    35.547041   47.432000    174.330531
# Solids           1278.0  22383.991018  9101.010208  728.750830  15668.985035
# Chloramines      1278.0      7.169338     1.702988    0.352000      6.094134
# Sulfate           985.0    332.566990    47.692818  129.000000    300.763772
# Conductivity     1278.0    425.383800    82.048446  201.619737    360.939023
# Organic_carbon   1278.0     14.160893     3.263907    2.200000     12.033897
# Trihalomethanes  1223.0     66.539684    16.327419    8.175876     56.014249
# Turbidity        1278.0      3.968328     0.780842    1.492207      3.430909
# Potability       1278.0      1.000000     0.000000    1.000000      1.000000
#
#                           50%           75%           max
# ph                   7.036752      7.933068     13.175402
# Hardness           196.632907    218.003420    323.124000
# Solids           21199.386614  27973.236446  56488.672413
# Chloramines          7.215163      8.199261     13.127000
# Sulfate            331.838167    365.941346    481.030642
# Conductivity       420.712729    484.155911    695.369528
# Organic_carbon      14.162809     16.356245     23.604298
# Trihalomethanes     66.678214     77.380975    124.000000
# Turbidity            3.958576      4.509569      6.494249
# Potability           1.000000      1.000000      1.000000

# %%
# Xem trung bình, trung vị của 3 cột có giá trị null
print(df[df['Potability']==0][['ph','Sulfate','Trihalomethanes']].mean()) 
print('\n')
print(df[df['Potability']==0][['ph','Sulfate','Trihalomethanes']].median())
# Out:
# ph                   7.085378
# Sulfate            334.564290
# Trihalomethanes     66.303555
# dtype: float64
#
#
# ph                   7.035456
# Sulfate            333.389426
# Trihalomethanes     66.542198
# dtype: float64

# %%
df[df['Potability']==1][['ph','Sulfate','Trihalomethanes']].mean()
print('\n')
df[df['Potability']==1][['ph','Sulfate','Trihalomethanes']].median()
# Out:
# ph                   7.036752
# Sulfate            331.838167
# Trihalomethanes     66.678214
# dtype: float64

# %% [markdown]
# # Chia train test

# %%
X = df.drop('Potability', axis=1)
y = df['Potability']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# %% [markdown]
# ## Điền null

# %%
X_train_filled = X_train.copy()
X_test_filled = X_test.copy()

# Fill cho từng nhãn 0 và 1
for label_value in [0, 1]:
    # Lấy chỉ số nhóm theo nhãn
    group_train_idx = y_train[y_train == label_value].index
    group_train = X_train.loc[group_train_idx]

    # Fit + transform toàn bộ cột
    imputer = KNNImputer(n_neighbors=5)
    imputed = imputer.fit_transform(group_train)
    X_train_filled.loc[group_train_idx] = pd.DataFrame(
        imputed, columns=X_train.columns, index=group_train_idx
    )

# Dùng nhóm train đã fit để fill cho test
for label_value in [0, 1]:
    # Tách nhóm train theo nhãn
    group_train_idx = y_train[y_train == label_value].index
    group_train = X_train.loc[group_train_idx]

    # Tách nhóm test theo nhãn
    group_test_idx = y_test[y_test == label_value].index
    group_test = X_test.loc[group_test_idx]

    # Fit trên train + transform test
    imputer = KNNImputer(n_neighbors=5)
    imputer.fit(group_train)
    imputed = imputer.transform(group_test)

    X_test_filled.loc[group_test_idx] = pd.DataFrame(
        imputed, columns=X_test.columns, index=group_test_idx
    )

# %%
print(X_train_filled.isnull().sum()[X_train_filled.isnull().sum() > 0])
print(X_test_filled.isnull().sum()[X_test_filled.isnull().sum() > 0])
# Out:
# Series([], dtype: int64)
# Series([], dtype: int64)

# %%
X_train_filled.shape, X_test_filled.shape
# Out:
# ((2293, 9), (983, 9))

# %%
# Biến đầu vào
X_train_filled.columns
# Out:
# Index(['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
#        'Organic_carbon', 'Trihalomethanes', 'Turbidity'],
#       dtype='object')

# %% [markdown]
# # Chạy mô hình

# %%
dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train_filled, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred = dt.predict(X_test_filled)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.66      0.66       600
#            1       0.48      0.50      0.49       383
#
#     accuracy                           0.60       983
#    macro avg       0.58      0.58      0.58       983
# weighted avg       0.60      0.60      0.60       983

# %%
cm = confusion_matrix(y_test, y_pred)
display_cm = ConfusionMatrixDisplay(confusion_matrix=cm)
display_cm.plot(cmap='Blues')

# %%
plt.figure(figsize=(20,10))
plot_tree(dt, filled=True, feature_names=df.columns[:-1], class_names=['0', '1'])
plt.show()

# %% [markdown]
# # Tối ưu mô hình

# %%
def compute_inverse_class_weights(label_col):
    counter = Counter(label_col)
    total = sum(counter.values())
    
    class_freq = {cls: count / total for cls, count in counter.items()}
    
    max_freq = max(class_freq.values())
    class_weights = {cls: round(max_freq / freq, 2) for cls, freq in class_freq.items()}
    
    return class_weights

weights = compute_inverse_class_weights(y_train)
weights
# Out:
# {1: 1.56, 0: 1.0}

# %%
param = {
    'max_depth': [4, 6],
    'min_samples_split': [2, 8],
    'min_samples_leaf': [1, 4],
    'criterion': ['entropy', 'gini'],
    'class_weight': [None, weights]
}

scoring=make_scorer(precision_score, pos_label=1)

# %%
grid = GridSearchCV(
    estimator=DecisionTreeClassifier(random_state=42),
    param_grid=param,
    scoring=scoring,
    cv=5,                                                 
    n_jobs=-1,
    verbose=1
)

grid.fit(X_train_filled, y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=42), n_jobs=-1,
#              param_grid={'class_weight': [None, {0: 1.0, 1: 1.56}],
#                          'criterion': ['entropy', 'gini'], 'max_depth': [4, 6],
#                          'min_samples_leaf': [1, 4],
#                          'min_samples_split': [2, 8]},
#              scoring=make_scorer(precision_score, response_method='predict', pos_label=1),
#              verbose=1)

# %%
grid.best_params_
# Out:
# {'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': 4,
#  'min_samples_leaf': 4,
#  'min_samples_split': 2}

# %%
y_proba = grid.predict_proba(X_test_filled)[:, 1]

# %%
# Tạo 1 chuỗi threshold (ngưỡng) từ 0.0 đến 1.0, bước nhảy 0.01
threshold = np.arange(0.0, 1.01, 0.01)

# 1 mảng lưu kết quả từ confusion matrix (ma trận nhầm lẫn)
res = []

for t in threshold:
    y_pred = (y_proba >= t).astype(int)
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    res.append((t, fp, fn, tp, tn))

# %%
df_thresh = pd.DataFrame(res, columns=['Threshold', 'FP', 'FN', 'TP', 'TN'])
df_thresh['Precision'] = df_thresh['TP'] / (df_thresh['TP'] + df_thresh['FP'])
df_thresh['Recall'] = df_thresh['TP'] / (df_thresh['TP'] + df_thresh['FN'])

# %%
plt.figure(figsize=(10,6))
plt.plot(df_thresh["Threshold"], df_thresh["FP"], label="False Positives", color="red")
plt.plot(df_thresh["Threshold"], df_thresh["FN"], label="False Negatives", color="blue")
plt.xlabel("Threshold")
plt.ylabel("Count")
plt.title("FP & FN vs Threshold")
plt.legend()
plt.grid()
plt.show()

# %%
# In ra confusion matrix & classification report theo nhiều threshold khác nhau
for t in threshold:
    print(f"Threshold: {t:.2f}")
    y_pred = (y_proba >= t).astype(int)
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
# Out:
# Threshold: 0.00
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       600
#            1       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.01
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       600
#            1       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.02
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       600
#            1       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.03
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       600
#            1       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.04
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       600
#            1       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.05
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       600
#            1       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.06
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       600
#            1       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.07
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       600
#            1       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.08
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       600
#            1       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.09
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       600
#            1       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.10
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       600
#            1       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.11
# [[  0 600]
#  [  0 383]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       600
#            1       0.39      1.00      0.56       383
#
#     accuracy                           0.39       983
#    macro avg       0.19      0.50      0.28       983
# weighted avg       0.15      0.39      0.22       983
#
# Threshold: 0.12
# [[ 17 583]
#  [ 14 369]]
#               precision    recall  f1-score   support
#
#            0       0.55      0.03      0.05       600
#            1       0.39      0.96      0.55       383
#
#     accuracy                           0.39       983
#    macro avg       0.47      0.50      0.30       983
# weighted avg       0.49      0.39      0.25       983
#
# Threshold: 0.13
# [[ 17 583]
#  [ 14 369]]
#               precision    recall  f1-score   support
#
#            0       0.55      0.03      0.05       600
#            1       0.39      0.96      0.55       383
#
#     accuracy                           0.39       983
#    macro avg       0.47      0.50      0.30       983
# weighted avg       0.49      0.39      0.25       983
#
# Threshold: 0.14
# [[ 17 583]
#  [ 14 369]]
#               precision    recall  f1-score   support
#
#            0       0.55      0.03      0.05       600
#            1       0.39      0.96      0.55       383
#
#     accuracy                           0.39       983
#    macro avg       0.47      0.50      0.30       983
# weighted avg       0.49      0.39      0.25       983
#
# Threshold: 0.15
# [[ 17 583]
#  [ 14 369]]
#               precision    recall  f1-score   support
#
#            0       0.55      0.03      0.05       600
#            1       0.39      0.96      0.55       383
#
#     accuracy                           0.39       983
#    macro avg       0.47      0.50      0.30       983
# weighted avg       0.49      0.39      0.25       983
#
# Threshold: 0.16
# [[ 17 583]
#  [ 14 369]]
#               precision    recall  f1-score   support
#
#            0       0.55      0.03      0.05       600
#            1       0.39      0.96      0.55       383
#
#     accuracy                           0.39       983
#    macro avg       0.47      0.50      0.30       983
# weighted avg       0.49      0.39      0.25       983
#
# Threshold: 0.17
# [[ 17 583]
#  [ 14 369]]
#               precision    recall  f1-score   support
#
#            0       0.55      0.03      0.05       600
#            1       0.39      0.96      0.55       383
#
#     accuracy                           0.39       983
#    macro avg       0.47      0.50      0.30       983
# weighted avg       0.49      0.39      0.25       983
#
# Threshold: 0.18
# [[ 17 583]
#  [ 14 369]]
#               precision    recall  f1-score   support
#
#            0       0.55      0.03      0.05       600
#            1       0.39      0.96      0.55       383
#
#     accuracy                           0.39       983
#    macro avg       0.47      0.50      0.30       983
# weighted avg       0.49      0.39      0.25       983
#
# Threshold: 0.19
# [[ 17 583]
#  [ 14 369]]
#               precision    recall  f1-score   support
#
#            0       0.55      0.03      0.05       600
#            1       0.39      0.96      0.55       383
#
#     accuracy                           0.39       983
#    macro avg       0.47      0.50      0.30       983
# weighted avg       0.49      0.39      0.25       983
#
# Threshold: 0.20
# [[ 17 583]
#  [ 14 369]]
#               precision    recall  f1-score   support
#
#            0       0.55      0.03      0.05       600
#            1       0.39      0.96      0.55       383
#
#     accuracy                           0.39       983
#    macro avg       0.47      0.50      0.30       983
# weighted avg       0.49      0.39      0.25       983
#
# Threshold: 0.21
# [[ 68 532]
#  [ 30 353]]
#               precision    recall  f1-score   support
#
#            0       0.69      0.11      0.19       600
#            1       0.40      0.92      0.56       383
#
#     accuracy                           0.43       983
#    macro avg       0.55      0.52      0.38       983
# weighted avg       0.58      0.43      0.34       983
#
# Threshold: 0.22
# [[ 68 532]
#  [ 30 353]]
#               precision    recall  f1-score   support
#
#            0       0.69      0.11      0.19       600
#            1       0.40      0.92      0.56       383
#
#     accuracy                           0.43       983
#    macro avg       0.55      0.52      0.38       983
# weighted avg       0.58      0.43      0.34       983
#
# Threshold: 0.23
# [[107 493]
#  [ 36 347]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.18      0.29       600
#            1       0.41      0.91      0.57       383
#
#     accuracy                           0.46       983
#    macro avg       0.58      0.54      0.43       983
# weighted avg       0.62      0.46      0.40       983
#
# Threshold: 0.24
# [[271 329]
#  [118 265]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.45      0.55       600
#            1       0.45      0.69      0.54       383
#
#     accuracy                           0.55       983
#    macro avg       0.57      0.57      0.55       983
# weighted avg       0.60      0.55      0.55       983
#
# Threshold: 0.25
# [[271 329]
#  [118 265]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.45      0.55       600
#            1       0.45      0.69      0.54       383
#
#     accuracy                           0.55       983
#    macro avg       0.57      0.57      0.55       983
# weighted avg       0.60      0.55      0.55       983
#
# Threshold: 0.26
# [[271 329]
#  [118 265]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.45      0.55       600
#            1       0.45      0.69      0.54       383
#
#     accuracy                           0.55       983
#    macro avg       0.57      0.57      0.55       983
# weighted avg       0.60      0.55      0.55       983
#
# Threshold: 0.27
# [[271 329]
#  [118 265]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.45      0.55       600
#            1       0.45      0.69      0.54       383
#
#     accuracy                           0.55       983
#    macro avg       0.57      0.57      0.55       983
# weighted avg       0.60      0.55      0.55       983
#
# Threshold: 0.28
# [[271 329]
#  [118 265]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.45      0.55       600
#            1       0.45      0.69      0.54       383
#
#     accuracy                           0.55       983
#    macro avg       0.57      0.57      0.55       983
# weighted avg       0.60      0.55      0.55       983
#
# Threshold: 0.29
# [[271 329]
#  [118 265]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.45      0.55       600
#            1       0.45      0.69      0.54       383
#
#     accuracy                           0.55       983
#    macro avg       0.57      0.57      0.55       983
# weighted avg       0.60      0.55      0.55       983
#
# Threshold: 0.30
# [[271 329]
#  [118 265]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.45      0.55       600
#            1       0.45      0.69      0.54       383
#
#     accuracy                           0.55       983
#    macro avg       0.57      0.57      0.55       983
# weighted avg       0.60      0.55      0.55       983
#
# Threshold: 0.31
# [[271 329]
#  [118 265]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.45      0.55       600
#            1       0.45      0.69      0.54       383
#
#     accuracy                           0.55       983
#    macro avg       0.57      0.57      0.55       983
# weighted avg       0.60      0.55      0.55       983
#
# Threshold: 0.32
# [[271 329]
#  [118 265]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.45      0.55       600
#            1       0.45      0.69      0.54       383
#
#     accuracy                           0.55       983
#    macro avg       0.57      0.57      0.55       983
# weighted avg       0.60      0.55      0.55       983
#
# Threshold: 0.33
# [[271 329]
#  [118 265]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.45      0.55       600
#            1       0.45      0.69      0.54       383
#
#     accuracy                           0.55       983
#    macro avg       0.57      0.57      0.55       983
# weighted avg       0.60      0.55      0.55       983
#
# Threshold: 0.34
# [[271 329]
#  [118 265]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.45      0.55       600
#            1       0.45      0.69      0.54       383
#
#     accuracy                           0.55       983
#    macro avg       0.57      0.57      0.55       983
# weighted avg       0.60      0.55      0.55       983
#
# Threshold: 0.35
# [[271 329]
#  [118 265]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.45      0.55       600
#            1       0.45      0.69      0.54       383
#
#     accuracy                           0.55       983
#    macro avg       0.57      0.57      0.55       983
# weighted avg       0.60      0.55      0.55       983
#
# Threshold: 0.36
# [[271 329]
#  [118 265]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.45      0.55       600
#            1       0.45      0.69      0.54       383
#
#     accuracy                           0.55       983
#    macro avg       0.57      0.57      0.55       983
# weighted avg       0.60      0.55      0.55       983
#
# Threshold: 0.37
# [[271 329]
#  [118 265]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.45      0.55       600
#            1       0.45      0.69      0.54       383
#
#     accuracy                           0.55       983
#    macro avg       0.57      0.57      0.55       983
# weighted avg       0.60      0.55      0.55       983
#
# Threshold: 0.38
# [[271 329]
#  [118 265]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.45      0.55       600
#            1       0.45      0.69      0.54       383
#
#     accuracy                           0.55       983
#    macro avg       0.57      0.57      0.55       983
# weighted avg       0.60      0.55      0.55       983
#
# Threshold: 0.39
# [[271 329]
#  [118 265]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.45      0.55       600
#            1       0.45      0.69      0.54       383
#
#     accuracy                           0.55       983
#    macro avg       0.57      0.57      0.55       983
# weighted avg       0.60      0.55      0.55       983
#
# Threshold: 0.40
# [[271 329]
#  [118 265]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.45      0.55       600
#            1       0.45      0.69      0.54       383
#
#     accuracy                           0.55       983
#    macro avg       0.57      0.57      0.55       983
# weighted avg       0.60      0.55      0.55       983
#
# Threshold: 0.41
# [[500 100]
#  [273 110]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.83      0.73       600
#            1       0.52      0.29      0.37       383
#
#     accuracy                           0.62       983
#    macro avg       0.59      0.56      0.55       983
# weighted avg       0.60      0.62      0.59       983
#
# Threshold: 0.42
# [[513  87]
#  [283 100]]
#               precision    recall  f1-score   support
#
#            0       0.64      0.85      0.73       600
#            1       0.53      0.26      0.35       383
#
#     accuracy                           0.62       983
#    macro avg       0.59      0.56      0.54       983
# weighted avg       0.60      0.62      0.59       983
#
# Threshold: 0.43
# [[513  87]
#  [283 100]]
#               precision    recall  f1-score   support
#
#            0       0.64      0.85      0.73       600
#            1       0.53      0.26      0.35       383
#
#     accuracy                           0.62       983
#    macro avg       0.59      0.56      0.54       983
# weighted avg       0.60      0.62      0.59       983
#
# Threshold: 0.44
# [[513  87]
#  [283 100]]
#               precision    recall  f1-score   support
#
#            0       0.64      0.85      0.73       600
#            1       0.53      0.26      0.35       383
#
#     accuracy                           0.62       983
#    macro avg       0.59      0.56      0.54       983
# weighted avg       0.60      0.62      0.59       983
#
# Threshold: 0.45
# [[513  87]
#  [283 100]]
#               precision    recall  f1-score   support
#
#            0       0.64      0.85      0.73       600
#            1       0.53      0.26      0.35       383
#
#     accuracy                           0.62       983
#    macro avg       0.59      0.56      0.54       983
# weighted avg       0.60      0.62      0.59       983
#
# Threshold: 0.46
# [[513  87]
#  [283 100]]
#               precision    recall  f1-score   support
#
#            0       0.64      0.85      0.73       600
#            1       0.53      0.26      0.35       383
#
#     accuracy                           0.62       983
#    macro avg       0.59      0.56      0.54       983
# weighted avg       0.60      0.62      0.59       983
#
# Threshold: 0.47
# [[513  87]
#  [283 100]]
#               precision    recall  f1-score   support
#
#            0       0.64      0.85      0.73       600
#            1       0.53      0.26      0.35       383
#
#     accuracy                           0.62       983
#    macro avg       0.59      0.56      0.54       983
# weighted avg       0.60      0.62      0.59       983
#
# Threshold: 0.48
# [[513  87]
#  [283 100]]
#               precision    recall  f1-score   support
#
#            0       0.64      0.85      0.73       600
#            1       0.53      0.26      0.35       383
#
#     accuracy                           0.62       983
#    macro avg       0.59      0.56      0.54       983
# weighted avg       0.60      0.62      0.59       983
#
# Threshold: 0.49
# [[541  59]
#  [294  89]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.90      0.75       600
#            1       0.60      0.23      0.34       383
#
#     accuracy                           0.64       983
#    macro avg       0.62      0.57      0.54       983
# weighted avg       0.63      0.64      0.59       983
#
# Threshold: 0.50
# [[573  27]
#  [312  71]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.95      0.77       600
#            1       0.72      0.19      0.30       383
#
#     accuracy                           0.66       983
#    macro avg       0.69      0.57      0.53       983
# weighted avg       0.68      0.66      0.59       983
#
# Threshold: 0.51
# [[573  27]
#  [312  71]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.95      0.77       600
#            1       0.72      0.19      0.30       383
#
#     accuracy                           0.66       983
#    macro avg       0.69      0.57      0.53       983
# weighted avg       0.68      0.66      0.59       983
#
# Threshold: 0.52
# [[573  27]
#  [312  71]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.95      0.77       600
#            1       0.72      0.19      0.30       383
#
#     accuracy                           0.66       983
#    macro avg       0.69      0.57      0.53       983
# weighted avg       0.68      0.66      0.59       983
#
# Threshold: 0.53
# [[573  27]
#  [312  71]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.95      0.77       600
#            1       0.72      0.19      0.30       383
#
#     accuracy                           0.66       983
#    macro avg       0.69      0.57      0.53       983
# weighted avg       0.68      0.66      0.59       983
#
# Threshold: 0.54
# [[573  27]
#  [312  71]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.95      0.77       600
#            1       0.72      0.19      0.30       383
#
#     accuracy                           0.66       983
#    macro avg       0.69      0.57      0.53       983
# weighted avg       0.68      0.66      0.59       983
#
# Threshold: 0.55
# [[573  27]
#  [312  71]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.95      0.77       600
#            1       0.72      0.19      0.30       383
#
#     accuracy                           0.66       983
#    macro avg       0.69      0.57      0.53       983
# weighted avg       0.68      0.66      0.59       983
#
# Threshold: 0.56
# [[573  27]
#  [312  71]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.95      0.77       600
#            1       0.72      0.19      0.30       383
#
#     accuracy                           0.66       983
#    macro avg       0.69      0.57      0.53       983
# weighted avg       0.68      0.66      0.59       983
#
# Threshold: 0.57
# [[573  27]
#  [312  71]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.95      0.77       600
#            1       0.72      0.19      0.30       383
#
#     accuracy                           0.66       983
#    macro avg       0.69      0.57      0.53       983
# weighted avg       0.68      0.66      0.59       983
#
# Threshold: 0.58
# [[573  27]
#  [312  71]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.95      0.77       600
#            1       0.72      0.19      0.30       383
#
#     accuracy                           0.66       983
#    macro avg       0.69      0.57      0.53       983
# weighted avg       0.68      0.66      0.59       983
#
# Threshold: 0.59
# [[573  27]
#  [314  69]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.95      0.77       600
#            1       0.72      0.18      0.29       383
#
#     accuracy                           0.65       983
#    macro avg       0.68      0.57      0.53       983
# weighted avg       0.67      0.65      0.58       983
#
# Threshold: 0.60
# [[573  27]
#  [314  69]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.95      0.77       600
#            1       0.72      0.18      0.29       383
#
#     accuracy                           0.65       983
#    macro avg       0.68      0.57      0.53       983
# weighted avg       0.67      0.65      0.58       983
#
# Threshold: 0.61
# [[573  27]
#  [314  69]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.95      0.77       600
#            1       0.72      0.18      0.29       383
#
#     accuracy                           0.65       983
#    macro avg       0.68      0.57      0.53       983
# weighted avg       0.67      0.65      0.58       983
#
# Threshold: 0.62
# [[573  27]
#  [314  69]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.95      0.77       600
#            1       0.72      0.18      0.29       383
#
#     accuracy                           0.65       983
#    macro avg       0.68      0.57      0.53       983
# weighted avg       0.67      0.65      0.58       983
#
# Threshold: 0.63
# [[573  27]
#  [314  69]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.95      0.77       600
#            1       0.72      0.18      0.29       383
#
#     accuracy                           0.65       983
#    macro avg       0.68      0.57      0.53       983
# weighted avg       0.67      0.65      0.58       983
#
# Threshold: 0.64
# [[573  27]
#  [314  69]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.95      0.77       600
#            1       0.72      0.18      0.29       383
#
#     accuracy                           0.65       983
#    macro avg       0.68      0.57      0.53       983
# weighted avg       0.67      0.65      0.58       983
#
# Threshold: 0.65
# [[573  27]
#  [314  69]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.95      0.77       600
#            1       0.72      0.18      0.29       383
#
#     accuracy                           0.65       983
#    macro avg       0.68      0.57      0.53       983
# weighted avg       0.67      0.65      0.58       983
#
# Threshold: 0.66
# [[573  27]
#  [314  69]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.95      0.77       600
#            1       0.72      0.18      0.29       383
#
#     accuracy                           0.65       983
#    macro avg       0.68      0.57      0.53       983
# weighted avg       0.67      0.65      0.58       983
#
# Threshold: 0.67
# [[575  25]
#  [315  68]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.96      0.77       600
#            1       0.73      0.18      0.29       383
#
#     accuracy                           0.65       983
#    macro avg       0.69      0.57      0.53       983
# weighted avg       0.68      0.65      0.58       983
#
# Threshold: 0.68
# [[575  25]
#  [315  68]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.96      0.77       600
#            1       0.73      0.18      0.29       383
#
#     accuracy                           0.65       983
#    macro avg       0.69      0.57      0.53       983
# weighted avg       0.68      0.65      0.58       983
#
# Threshold: 0.69
# [[575  25]
#  [315  68]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.96      0.77       600
#            1       0.73      0.18      0.29       383
#
#     accuracy                           0.65       983
#    macro avg       0.69      0.57      0.53       983
# weighted avg       0.68      0.65      0.58       983
#
# Threshold: 0.70
# [[575  25]
#  [315  68]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.96      0.77       600
#            1       0.73      0.18      0.29       383
#
#     accuracy                           0.65       983
#    macro avg       0.69      0.57      0.53       983
# weighted avg       0.68      0.65      0.58       983
#
# Threshold: 0.71
# [[575  25]
#  [315  68]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.96      0.77       600
#            1       0.73      0.18      0.29       383
#
#     accuracy                           0.65       983
#    macro avg       0.69      0.57      0.53       983
# weighted avg       0.68      0.65      0.58       983
#
# Threshold: 0.72
# [[576  24]
#  [316  67]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.96      0.77       600
#            1       0.74      0.17      0.28       383
#
#     accuracy                           0.65       983
#    macro avg       0.69      0.57      0.53       983
# weighted avg       0.68      0.65      0.58       983
#
# Threshold: 0.73
# [[576  24]
#  [316  67]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.96      0.77       600
#            1       0.74      0.17      0.28       383
#
#     accuracy                           0.65       983
#    macro avg       0.69      0.57      0.53       983
# weighted avg       0.68      0.65      0.58       983
#
# Threshold: 0.74
# [[576  24]
#  [316  67]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.96      0.77       600
#            1       0.74      0.17      0.28       383
#
#     accuracy                           0.65       983
#    macro avg       0.69      0.57      0.53       983
# weighted avg       0.68      0.65      0.58       983
#
# Threshold: 0.75
# [[576  24]
#  [316  67]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.96      0.77       600
#            1       0.74      0.17      0.28       383
#
#     accuracy                           0.65       983
#    macro avg       0.69      0.57      0.53       983
# weighted avg       0.68      0.65      0.58       983
#
# Threshold: 0.76
# [[590  10]
#  [351  32]]
#               precision    recall  f1-score   support
#
#            0       0.63      0.98      0.77       600
#            1       0.76      0.08      0.15       383
#
#     accuracy                           0.63       983
#    macro avg       0.69      0.53      0.46       983
# weighted avg       0.68      0.63      0.53       983
#
# Threshold: 0.77
# [[590  10]
#  [351  32]]
#               precision    recall  f1-score   support
#
#            0       0.63      0.98      0.77       600
#            1       0.76      0.08      0.15       383
#
#     accuracy                           0.63       983
#    macro avg       0.69      0.53      0.46       983
# weighted avg       0.68      0.63      0.53       983
#
# Threshold: 0.78
# [[590  10]
#  [351  32]]
#               precision    recall  f1-score   support
#
#            0       0.63      0.98      0.77       600
#            1       0.76      0.08      0.15       383
#
#     accuracy                           0.63       983
#    macro avg       0.69      0.53      0.46       983
# weighted avg       0.68      0.63      0.53       983
#
# Threshold: 0.79
# [[590  10]
#  [351  32]]
#               precision    recall  f1-score   support
#
#            0       0.63      0.98      0.77       600
#            1       0.76      0.08      0.15       383
#
#     accuracy                           0.63       983
#    macro avg       0.69      0.53      0.46       983
# weighted avg       0.68      0.63      0.53       983
#
# Threshold: 0.80
# [[590  10]
#  [351  32]]
#               precision    recall  f1-score   support
#
#            0       0.63      0.98      0.77       600
#            1       0.76      0.08      0.15       383
#
#     accuracy                           0.63       983
#    macro avg       0.69      0.53      0.46       983
# weighted avg       0.68      0.63      0.53       983
#
# Threshold: 0.81
# [[596   4]
#  [360  23]]
#               precision    recall  f1-score   support
#
#            0       0.62      0.99      0.77       600
#            1       0.85      0.06      0.11       383
#
#     accuracy                           0.63       983
#    macro avg       0.74      0.53      0.44       983
# weighted avg       0.71      0.63      0.51       983
#
# Threshold: 0.82
# [[596   4]
#  [360  23]]
#               precision    recall  f1-score   support
#
#            0       0.62      0.99      0.77       600
#            1       0.85      0.06      0.11       383
#
#     accuracy                           0.63       983
#    macro avg       0.74      0.53      0.44       983
# weighted avg       0.71      0.63      0.51       983
#
# Threshold: 0.83
# [[596   4]
#  [360  23]]
#               precision    recall  f1-score   support
#
#            0       0.62      0.99      0.77       600
#            1       0.85      0.06      0.11       383
#
#     accuracy                           0.63       983
#    macro avg       0.74      0.53      0.44       983
# weighted avg       0.71      0.63      0.51       983
#
# Threshold: 0.84
# [[596   4]
#  [360  23]]
#               precision    recall  f1-score   support
#
#            0       0.62      0.99      0.77       600
#            1       0.85      0.06      0.11       383
#
#     accuracy                           0.63       983
#    macro avg       0.74      0.53      0.44       983
# weighted avg       0.71      0.63      0.51       983
#
# Threshold: 0.85
# [[596   4]
#  [360  23]]
#               precision    recall  f1-score   support
#
#            0       0.62      0.99      0.77       600
#            1       0.85      0.06      0.11       383
#
#     accuracy                           0.63       983
#    macro avg       0.74      0.53      0.44       983
# weighted avg       0.71      0.63      0.51       983
#
# Threshold: 0.86
# [[596   4]
#  [362  21]]
#               precision    recall  f1-score   support
#
#            0       0.62      0.99      0.77       600
#            1       0.84      0.05      0.10       383
#
#     accuracy                           0.63       983
#    macro avg       0.73      0.52      0.43       983
# weighted avg       0.71      0.63      0.51       983
#
# Threshold: 0.87
# [[596   4]
#  [362  21]]
#               precision    recall  f1-score   support
#
#            0       0.62      0.99      0.77       600
#            1       0.84      0.05      0.10       383
#
#     accuracy                           0.63       983
#    macro avg       0.73      0.52      0.43       983
# weighted avg       0.71      0.63      0.51       983
#
# Threshold: 0.88
# [[596   4]
#  [362  21]]
#               precision    recall  f1-score   support
#
#            0       0.62      0.99      0.77       600
#            1       0.84      0.05      0.10       383
#
#     accuracy                           0.63       983
#    macro avg       0.73      0.52      0.43       983
# weighted avg       0.71      0.63      0.51       983
#
# Threshold: 0.89
# [[596   4]
#  [362  21]]
#               precision    recall  f1-score   support
#
#            0       0.62      0.99      0.77       600
#            1       0.84      0.05      0.10       383
#
#     accuracy                           0.63       983
#    macro avg       0.73      0.52      0.43       983
# weighted avg       0.71      0.63      0.51       983
#
# Threshold: 0.90
# [[596   4]
#  [362  21]]
#               precision    recall  f1-score   support
#
#            0       0.62      0.99      0.77       600
#            1       0.84      0.05      0.10       383
#
#     accuracy                           0.63       983
#    macro avg       0.73      0.52      0.43       983
# weighted avg       0.71      0.63      0.51       983
#
# Threshold: 0.91
# [[596   4]
#  [362  21]]
#               precision    recall  f1-score   support
#
#            0       0.62      0.99      0.77       600
#            1       0.84      0.05      0.10       383
#
#     accuracy                           0.63       983
#    macro avg       0.73      0.52      0.43       983
# weighted avg       0.71      0.63      0.51       983
#
# Threshold: 0.92
# [[596   4]
#  [362  21]]
#               precision    recall  f1-score   support
#
#            0       0.62      0.99      0.77       600
#            1       0.84      0.05      0.10       383
#
#     accuracy                           0.63       983
#    macro avg       0.73      0.52      0.43       983
# weighted avg       0.71      0.63      0.51       983
#
# Threshold: 0.93
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#            0       0.61      1.00      0.76       600
#            1       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.94
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#            0       0.61      1.00      0.76       600
#            1       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.95
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#            0       0.61      1.00      0.76       600
#            1       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.96
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#            0       0.61      1.00      0.76       600
#            1       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.97
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#            0       0.61      1.00      0.76       600
#            1       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.98
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#            0       0.61      1.00      0.76       600
#            1       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 0.99
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#            0       0.61      1.00      0.76       600
#            1       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983
#
# Threshold: 1.00
# [[600   0]
#  [383   0]]
#               precision    recall  f1-score   support
#
#            0       0.61      1.00      0.76       600
#            1       0.00      0.00      0.00       383
#
#     accuracy                           0.61       983
#    macro avg       0.31      0.50      0.38       983
# weighted avg       0.37      0.61      0.46       983

# %%
y_pred_best = (y_proba >= 0.58).astype(int)

# %%
print(classification_report(y_test, y_pred_best))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      0.95      0.77       600
#            1       0.72      0.19      0.30       383
#
#     accuracy                           0.66       983
#    macro avg       0.69      0.57      0.53       983
# weighted avg       0.68      0.66      0.59       983

# %%
cm_best = confusion_matrix(y_test, y_pred_best)
display_cm_best = ConfusionMatrixDisplay(confusion_matrix=cm_best)
display_cm_best.plot(cmap='Blues')

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_proba)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label='AUC = %0.2f' % roc_auc)
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')  # đường random guess
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20,10))
plot_tree(grid.best_estimator_, filled=True, feature_names=df.columns[:-1], class_names=['0', '1'])
plt.show()

# %% [markdown]
# # Kiểm tra độ quan trọng của thuộc tính đến mô hình

# %%
def check_importance(model, feature_names):
    importances = model.feature_importances_
    importance_df = pd.DataFrame({
        'Feature': feature_names,
        'Importance': importances
    }).sort_values(by='Importance', ascending=False)
    
    # Lọc các feature có độ quan trọng > 0
    importance_df = importance_df[importance_df['Importance'] > 0]
    return importance_df
    
    print(importance_df)

check_importance(grid.best_estimator_, df.columns[:-1])
# Out:
#        Feature  Importance
# 0           ph    0.390351
# 4      Sulfate    0.248231
# 2       Solids    0.197283
# 3  Chloramines    0.100217
# 1     Hardness    0.063918

# %%
importance_df = check_importance(grid.best_estimator_, X_train_filled.columns)
plt.figure(figsize=(10,6))
sns.barplot(data=importance_df, x='Importance', y='Feature')
plt.show()
